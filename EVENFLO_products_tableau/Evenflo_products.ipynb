# %%
import pandas as pd

# %%
evenflo_product_df = pd.read_csv("EVENFLO_project.csv")

# %%
evenflo_product_df.dtypes
# Out:
# MARCA                      object
# SUB-CATEGORIA              object
# CANAL                      object
# SKU                       float64
# CÓDIGO DE BARRAS          float64
# PRODUCTO                   object
# Ciudades                   object
# Unidades distribuidas      object
#  Tamaño                    object
# 2021 ENERO                 object
# 2021 FEBRERO               object
# 2021 MARZO                 object
# 2021 ABRIL                 object
# 2021 MAYO                  object
# 2021 JUNIO                 object
# 2022 ENERO                 object
# 2022 FEBRERO               object
# 2022 MARZO                 object
# 2022 ABRIL                 object
# 2022 MAYO                  object
# 2022 JUNIO                 object
#  Total 2021                object
#  Total 2022                object
#  Total general             object
# dtype: object

# %%
evenflo_product_df.head()
# Out:
#      MARCA SUB-CATEGORIA         CANAL      SKU  CÓDIGO DE BARRAS  \
# 0  INFANTI     BIBERONES  Autoservicios  1275.0      7.501028e+12
# 1  INFANTI     BIBERONES  Autoservicios  1281.0      7.501028e+12
# 2  INFANTI     BIBERONES  Autoservicios  1301.0      7.501028e+12
# 3  INFANTI     BIBERONES  Autoservicios  1302.0      7.501028e+12
# 4  INFANTI     BIBERONES  Autoservicios  7200.0      7.501028e+12
#
#            PRODUCTO          Ciudades Unidades distribuidas   Tamaño   \
# 0  BIB FOREST 20 OZ  Ciudad de México                 10,000     0 OZ
# 1     BIB TWIST 8OZ         Monterrey                 10,001      8OZ
# 2    BIB FOREST 8OZ       Guadalajara                 10,002      8OZ
# 3    BIB FOREST 4OZ       Guadalajara                 10,003      4OZ
# 4    BIB DREAMS 4OZ         Monterrey                 10,004      4OZ
#
#   2021 ENERO  ... 2021 JUNIO 2022 ENERO 2022 FEBRERO 2022 MARZO 2022 ABRIL  \
# ...

# %%
evenflo_product_df.to_csv("EVENFLO-project.csv", index=False)
